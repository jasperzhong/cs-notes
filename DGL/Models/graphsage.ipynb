# %% [markdown]
# ## Graph Sample and Aggregate (GraphSAGE)
#
# Paper:  [Inductive Representation Learning on Large Graphs](https://www-cs-faculty.stanford.edu/people/jure/pubs/graphsage-nips17.pdf) (NIPS 2017)
#
# **Message Passing Perspective**
#
# |Notion | Meaning |
# |---|---|
# |$\mathcal{G}$ = $(V, E)$ | Input graph |
# |$x_v$ | Node features for node $v\in V$|
# |$h_v$ | Node embedding for node $v\in V$ |
# |$\mathcal{N}(v)$ | Neighbours of node $v\in V$|
#
# Initial:
# $$h^{(0)}_v = x_v , \forall v \in V .$$
#
# Aggregate:
# $$h^{(l)}_{\mathcal{N}(v)} \leftarrow \text{AGG}\{h^{(l-1)}_u, \forall u\in \mathcal{N}(v)\} .$$
#
# Update:
# $$h^{(l)}_v \leftarrow \text{ReLU}\left(W^{(l)} \cdot \text{CONCAT}\left(h^{(l-1)}_v, h^{(l)}_{\mathcal{N}(v)}\right)\right) .$$

# %% [markdown]
# ## Reproduce Results
#
# Metric: F1
#
# |Dataset | Reddit | PPI |
# |---| --- | --- |
# |GraphSAGE-mean | 0.950 | 0.598 |
# |Ours | 0.959 | 0.974 |
#
# Refererence of implementation: https://docs.dgl.ai/tutorials/blitz/3_message_passing.html

# %%
import time

import torch 
import torch.nn as nn
import torch.nn.functional as F
import dgl 
import dgl.function as fn
from dgl.data import RedditDataset, PPIDataset
import numpy as np
from sklearn.metrics import f1_score

# %%
class GraphSAGELayer(nn.Module):
    def __init__(self, in_feats, out_feats):
        super(GraphSAGELayer, self).__init__()
        self.linear = nn.Linear(in_feats * 2, out_feats)
    
    def forward(self, g, h):
        with g.local_scope():
            g.ndata['h'] = h
            g.update_all(message_func=fn.copy_u('h', 'm'), reduce_func=fn.mean('m', 'h_N'))
            h_N = g.ndata['h_N']
            h_total = torch.cat([h, h_N], dim=1)
            return self.linear(h_total)

# %%
# a two-layer GraphSAGE as described in the paper
class GraphSAGE(nn.Module):
    def __init__(self, in_feats, h_feats, num_classes):
        super(GraphSAGE, self).__init__()
        self.conv1 = GraphSAGELayer(in_feats, h_feats)
        self.conv2 = GraphSAGELayer(h_feats, num_classes)

    def forward(self, g, h):
        h = self.conv1(g, h)
        h = F.relu(h)
        h = self.conv2(g, h)
        return h

# %%
# we use the same configurations as the paper's
hidden_size = 256
lr = 1e-2
epochs = 200

# %%
def evaluate(model, g, features, labels, mask):
    model.eval()
    with torch.no_grad():
        logits = model(g, features)
        logits = logits[mask]
        labels = labels[mask]
        _, indices = torch.max(logits, dim=1)
        return f1_score(indices.cpu().numpy(), labels.cpu().numpy(), average='micro')

# %%
def main(dataset, device='cuda'):
    g = dataset[0]
    features = g.ndata['feat'].to(device)
    labels = g.ndata['label'].to(device)
    train_mask = g.ndata['train_mask'].to(device)
    val_mask = g.ndata['val_mask'].to(device)
    test_mask = g.ndata['test_mask'].to(device)
    in_feats = features.shape[1]
    n_classes = dataset.num_classes
    g = dgl.remove_self_loop(g)
    n_edges = g.number_of_edges()
    g = g.int().to(device)
    
    print(f"#nodes: {g.number_of_nodes()}, #edges: {g.number_of_edges()}")
    
    model = GraphSAGE(in_feats, hidden_size, n_classes)
    model.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    loss_fn = nn.CrossEntropyLoss()
    
    early_stopping_cnt = 0
    best_val = 100 # large enough
    for epoch in range(epochs):
        start = time.time()
        model.train()
        # forward
        logits = model(g, features)
        loss = loss_fn(logits[train_mask], labels[train_mask])
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        end = time.time()
        logits = model(g, features)
        val_loss = loss_fn(logits[val_mask], labels[val_mask])
        
        if val_loss < best_val:
            best_val = val_loss
            early_stopping_cnt = 0
        else:
            early_stopping_cnt += 1
            if early_stopping_cnt == 10:
                print("Early stopping (val loss does not decrease for 10 consecutive epochs).")
                break        
                
        print("Epoch {:03d} | Time(s) {:.4f} | Train Loss {:.4f} | Val Loss {:.4f} | ".format(epoch, end - start, loss.item(), val_loss.item()))
    
    f1 = evaluate(model, g, features, labels, test_mask)
    print("Test F1 {:.3f}".format(f1))

# %%
dataset = RedditDataset()
main(dataset)
# Out:
# #nodes: 232965, #edges: 114615892
# Epoch 000 | Time(s) 1.1911 | Train Loss 3.7194 | Val Loss 2.6151 |
# Epoch 001 | Time(s) 0.4856 | Train Loss 2.7078 | Val Loss 1.8982 |
# Epoch 002 | Time(s) 0.4837 | Train Loss 1.9473 | Val Loss 1.3232 |
# Epoch 003 | Time(s) 0.4855 | Train Loss 1.3681 | Val Loss 0.9192 |
# Epoch 004 | Time(s) 0.4853 | Train Loss 0.9821 | Val Loss 0.7158 |
# Epoch 005 | Time(s) 0.4863 | Train Loss 0.7571 | Val Loss 0.6174 |
# Epoch 006 | Time(s) 0.4840 | Train Loss 0.6250 | Val Loss 0.5222 |
# Epoch 007 | Time(s) 0.4873 | Train Loss 0.5357 | Val Loss 0.4646 |
# Epoch 008 | Time(s) 0.4870 | Train Loss 0.4993 | Val Loss 0.3998 |
# Epoch 009 | Time(s) 0.4818 | Train Loss 0.4423 | Val Loss 0.3646 |
# Epoch 010 | Time(s) 0.4872 | Train Loss 0.4016 | Val Loss 0.3873 |
# Epoch 011 | Time(s) 0.4871 | Train Loss 0.4243 | Val Loss 0.3513 |
# Epoch 012 | Time(s) 0.5027 | Train Loss 0.3760 | Val Loss 0.3539 |
# Epoch 013 | Time(s) 0.4861 | Train Loss 0.3717 | Val Loss 0.3689 |
# Epoch 014 | Time(s) 0.4853 | Train Loss 0.3748 | Val Loss 0.3763 |
# Epoch 015 | Time(s) 0.4857 | Train Loss 0.3697 | Val Loss 0.3780 |
# Epoch 016 | Time(s) 0.4879 | Train Loss 0.3614 | Val Loss 0.3699 |
# Epoch 017 | Time(s) 0.4869 | Train Loss 0.3481 | Val Loss 0.3563 |
# Epoch 018 | Time(s) 0.4870 | Train Loss 0.3344 | Val Loss 0.3323 |
# Epoch 019 | Time(s) 0.4835 | Train Loss 0.3128 | Val Loss 0.3119 |
# Epoch 020 | Time(s) 0.4868 | Train Loss 0.2952 | Val Loss 0.2969 |
# Epoch 021 | Time(s) 0.4819 | Train Loss 0.2829 | Val Loss 0.2822 |
# Epoch 022 | Time(s) 0.4841 | Train Loss 0.2709 | Val Loss 0.2666 |
# Epoch 023 | Time(s) 0.4821 | Train Loss 0.2563 | Val Loss 0.2573 |
# Epoch 024 | Time(s) 0.4854 | Train Loss 0.2469 | Val Loss 0.2538 |
# Epoch 025 | Time(s) 0.4822 | Train Loss 0.2426 | Val Loss 0.2503 |
# Epoch 026 | Time(s) 0.4821 | Train Loss 0.2373 | Val Loss 0.2427 |
# Epoch 027 | Time(s) 0.4859 | Train Loss 0.2255 | Val Loss 0.2342 |
# Epoch 028 | Time(s) 0.4802 | Train Loss 0.2122 | Val Loss 0.2297 |
# Epoch 029 | Time(s) 0.4806 | Train Loss 0.2031 | Val Loss 0.2293 |
# Epoch 030 | Time(s) 0.4832 | Train Loss 0.1972 | Val Loss 0.2297 |
# Epoch 031 | Time(s) 0.4800 | Train Loss 0.1924 | Val Loss 0.2272 |
# Epoch 032 | Time(s) 0.4818 | Train Loss 0.1861 | Val Loss 0.2227 |
# Epoch 033 | Time(s) 0.4808 | Train Loss 0.1794 | Val Loss 0.2175 |
# Epoch 034 | Time(s) 0.4799 | Train Loss 0.1729 | Val Loss 0.2118 |
# Epoch 035 | Time(s) 0.4807 | Train Loss 0.1662 | Val Loss 0.2056 |
# Epoch 036 | Time(s) 0.4804 | Train Loss 0.1591 | Val Loss 0.2011 |
# Epoch 037 | Time(s) 0.4805 | Train Loss 0.1532 | Val Loss 0.1987 |
# Epoch 038 | Time(s) 0.4798 | Train Loss 0.1495 | Val Loss 0.1968 |
# Epoch 039 | Time(s) 0.4799 | Train Loss 0.1456 | Val Loss 0.1950 |
# Epoch 040 | Time(s) 0.4804 | Train Loss 0.1414 | Val Loss 0.1931 |
# Epoch 041 | Time(s) 0.4801 | Train Loss 0.1367 | Val Loss 0.1911 |
# Epoch 042 | Time(s) 0.4805 | Train Loss 0.1318 | Val Loss 0.1901 |
# Epoch 043 | Time(s) 0.4808 | Train Loss 0.1281 | Val Loss 0.1894 |
# Epoch 044 | Time(s) 0.4807 | Train Loss 0.1248 | Val Loss 0.1882 |
# Epoch 045 | Time(s) 0.4802 | Train Loss 0.1216 | Val Loss 0.1862 |
# Epoch 046 | Time(s) 0.4805 | Train Loss 0.1181 | Val Loss 0.1843 |
# Epoch 047 | Time(s) 0.4804 | Train Loss 0.1146 | Val Loss 0.1825 |
# Epoch 048 | Time(s) 0.4810 | Train Loss 0.1111 | Val Loss 0.1809 |
# Epoch 049 | Time(s) 0.4806 | Train Loss 0.1079 | Val Loss 0.1798 |
# Epoch 050 | Time(s) 0.4808 | Train Loss 0.1049 | Val Loss 0.1792 |
# Epoch 051 | Time(s) 0.4805 | Train Loss 0.1024 | Val Loss 0.1786 |
# Epoch 052 | Time(s) 0.4801 | Train Loss 0.0999 | Val Loss 0.1779 |
# Epoch 053 | Time(s) 0.4804 | Train Loss 0.0971 | Val Loss 0.1768 |
# Epoch 054 | Time(s) 0.4810 | Train Loss 0.0941 | Val Loss 0.1766 |
# Epoch 055 | Time(s) 0.4803 | Train Loss 0.0917 | Val Loss 0.1767 |
# Epoch 056 | Time(s) 0.4863 | Train Loss 0.0896 | Val Loss 0.1766 |
# Epoch 057 | Time(s) 0.4859 | Train Loss 0.0875 | Val Loss 0.1761 |
# Epoch 058 | Time(s) 0.4876 | Train Loss 0.0851 | Val Loss 0.1755 |
# Epoch 059 | Time(s) 0.4869 | Train Loss 0.0828 | Val Loss 0.1752 |
# Epoch 060 | Time(s) 0.4865 | Train Loss 0.0806 | Val Loss 0.1751 |
# Epoch 061 | Time(s) 0.4868 | Train Loss 0.0786 | Val Loss 0.1752 |
# Epoch 062 | Time(s) 0.4863 | Train Loss 0.0767 | Val Loss 0.1752 |
# Epoch 063 | Time(s) 0.4827 | Train Loss 0.0748 | Val Loss 0.1751 |
# Epoch 064 | Time(s) 0.4862 | Train Loss 0.0729 | Val Loss 0.1752 |
# Epoch 065 | Time(s) 0.4823 | Train Loss 0.0710 | Val Loss 0.1755 |
# Epoch 066 | Time(s) 0.4874 | Train Loss 0.0692 | Val Loss 0.1759 |
# Epoch 067 | Time(s) 0.4837 | Train Loss 0.0675 | Val Loss 0.1764 |
# Epoch 068 | Time(s) 0.4860 | Train Loss 0.0659 | Val Loss 0.1767 |
# Epoch 069 | Time(s) 0.4862 | Train Loss 0.0643 | Val Loss 0.1769 |
# Early stopping (val loss does not decrease for 10 consecutive epochs).
# Test F1 0.959

# %%
# we use the same configurations as the paper's
hidden_size = 256
lr = 1e-3
epochs = 200

# %%
model = GraphSAGE(50, hidden_size, 121)
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
loss_fn = nn.CrossEntropyLoss()

# %%
train_dataset = PPIDataset(mode='train')
val_dataset = PPIDataset(mode='valid')
test_dataset = PPIDataset(mode='test')

early_stopping_cnt = 0
best_val = 100 # large enough
for epoch in range(epochs):
    train_loss = 0
    start = time.time()
    for g in train_dataset:
        features = g.ndata['feat']
        labels = g.ndata['label']
        logits = model(g, features)
        loss = loss_fn(logits, labels.argmax(dim=1))
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
    train_loss /= len(train_dataset)
    end = time.time()
    
    with torch.no_grad():
        val_loss = 0
        for g in val_dataset:
            features = g.ndata['feat']
            labels = g.ndata['label']
            logits = model(g, features)
            val_loss = loss_fn(logits, labels.argmax(dim=1))
        val_loss /= len(val_dataset)

    if val_loss < best_val:
        best_val = val_loss
        early_stopping_cnt = 0
    else:
        early_stopping_cnt += 1
        if early_stopping_cnt == 10:
            print("Early stopping (val loss does not decrease for 10 consecutive epochs).")
            break        
                
    print("Epoch {:03d} | Time(s) {:.4f} | Train Loss {:.4f} | Val Loss {:.4f} | ".format(epoch, end - start, train_loss, val_loss))


model.eval()
with torch.no_grad():
    total_pred = np.array([])
    total_labels = np.array([])
    for g in test_dataset:
        features = g.ndata['feat']
        labels = g.ndata['label']
        logits = model(g, features)
        _, indices = torch.max(logits, dim=1)
        total_pred = np.append(total_pred, indices.cpu().numpy())
        total_labels = np.append(total_labels, labels.argmax(dim=1).cpu().numpy())
    
    f1 = f1_score(total_pred, total_labels, average='micro')
    print("Test F1 {:.3f}".format(f1))
# Out:
# Epoch 000 | Time(s) 0.9862 | Train Loss 3.5365 | Val Loss 1.1641 |
# Epoch 001 | Time(s) 0.9264 | Train Loss 1.6464 | Val Loss 0.7393 |
# Epoch 002 | Time(s) 1.0114 | Train Loss 1.2514 | Val Loss 0.6692 |
# Epoch 003 | Time(s) 0.9163 | Train Loss 1.1785 | Val Loss 0.6490 |
# Epoch 004 | Time(s) 0.8818 | Train Loss 1.1348 | Val Loss 0.6324 |
# Epoch 005 | Time(s) 0.9318 | Train Loss 1.0976 | Val Loss 0.6175 |
# Epoch 006 | Time(s) 0.8670 | Train Loss 1.0635 | Val Loss 0.6038 |
# Epoch 007 | Time(s) 0.8117 | Train Loss 1.0314 | Val Loss 0.5909 |
# Epoch 008 | Time(s) 0.8762 | Train Loss 1.0010 | Val Loss 0.5786 |
# Epoch 009 | Time(s) 0.9118 | Train Loss 0.9722 | Val Loss 0.5669 |
# Epoch 010 | Time(s) 0.9682 | Train Loss 0.9448 | Val Loss 0.5558 |
# Epoch 011 | Time(s) 0.9459 | Train Loss 0.9185 | Val Loss 0.5450 |
# Epoch 012 | Time(s) 0.9124 | Train Loss 0.8930 | Val Loss 0.5344 |
# Epoch 013 | Time(s) 0.9441 | Train Loss 0.8684 | Val Loss 0.5242 |
# Epoch 014 | Time(s) 0.8958 | Train Loss 0.8445 | Val Loss 0.5142 |
# Epoch 015 | Time(s) 0.8717 | Train Loss 0.8215 | Val Loss 0.5046 |
# Epoch 016 | Time(s) 0.8513 | Train Loss 0.7993 | Val Loss 0.4952 |
# Epoch 017 | Time(s) 0.8486 | Train Loss 0.7778 | Val Loss 0.4860 |
# Epoch 018 | Time(s) 0.8962 | Train Loss 0.7571 | Val Loss 0.4770 |
# Epoch 019 | Time(s) 0.8965 | Train Loss 0.7371 | Val Loss 0.4682 |
# Epoch 020 | Time(s) 0.9969 | Train Loss 0.7177 | Val Loss 0.4597 |
# Epoch 021 | Time(s) 0.9079 | Train Loss 0.6991 | Val Loss 0.4514 |
# Epoch 022 | Time(s) 0.9017 | Train Loss 0.6810 | Val Loss 0.4433 |
# Epoch 023 | Time(s) 0.9054 | Train Loss 0.6636 | Val Loss 0.4352 |
# Epoch 024 | Time(s) 0.9617 | Train Loss 0.6468 | Val Loss 0.4274 |
# Epoch 025 | Time(s) 0.9536 | Train Loss 0.6305 | Val Loss 0.4196 |
# Epoch 026 | Time(s) 0.9568 | Train Loss 0.6146 | Val Loss 0.4121 |
# Epoch 027 | Time(s) 0.8829 | Train Loss 0.5991 | Val Loss 0.4046 |
# Epoch 028 | Time(s) 0.9006 | Train Loss 0.5842 | Val Loss 0.3974 |
# Epoch 029 | Time(s) 0.9116 | Train Loss 0.5698 | Val Loss 0.3904 |
# Epoch 030 | Time(s) 0.8852 | Train Loss 0.5558 | Val Loss 0.3835 |
# Epoch 031 | Time(s) 0.8629 | Train Loss 0.5423 | Val Loss 0.3768 |
# Epoch 032 | Time(s) 0.8704 | Train Loss 0.5292 | Val Loss 0.3703 |
# Epoch 033 | Time(s) 0.8802 | Train Loss 0.5165 | Val Loss 0.3639 |
# Epoch 034 | Time(s) 0.8717 | Train Loss 0.5043 | Val Loss 0.3577 |
# Epoch 035 | Time(s) 0.8832 | Train Loss 0.4924 | Val Loss 0.3517 |
# Epoch 036 | Time(s) 0.8583 | Train Loss 0.4810 | Val Loss 0.3458 |
# Epoch 037 | Time(s) 0.8816 | Train Loss 0.4699 | Val Loss 0.3402 |
# Epoch 038 | Time(s) 0.9077 | Train Loss 0.4591 | Val Loss 0.3346 |
# Epoch 039 | Time(s) 0.8271 | Train Loss 0.4487 | Val Loss 0.3292 |
# Epoch 040 | Time(s) 0.8655 | Train Loss 0.4387 | Val Loss 0.3239 |
# Epoch 041 | Time(s) 0.9433 | Train Loss 0.4289 | Val Loss 0.3186 |
# Epoch 042 | Time(s) 0.8387 | Train Loss 0.4194 | Val Loss 0.3135 |
# Epoch 043 | Time(s) 0.8477 | Train Loss 0.4103 | Val Loss 0.3086 |
# Epoch 044 | Time(s) 0.8509 | Train Loss 0.4015 | Val Loss 0.3039 |
# Epoch 045 | Time(s) 0.8427 | Train Loss 0.3929 | Val Loss 0.2992 |
# Epoch 046 | Time(s) 0.8411 | Train Loss 0.3845 | Val Loss 0.2947 |
# Epoch 047 | Time(s) 0.8824 | Train Loss 0.3765 | Val Loss 0.2903 |
# Epoch 048 | Time(s) 0.8613 | Train Loss 0.3687 | Val Loss 0.2859 |
# Epoch 049 | Time(s) 0.8764 | Train Loss 0.3611 | Val Loss 0.2817 |
# Epoch 050 | Time(s) 0.8926 | Train Loss 0.3537 | Val Loss 0.2777 |
# Epoch 051 | Time(s) 0.8903 | Train Loss 0.3466 | Val Loss 0.2738 |
# Epoch 052 | Time(s) 0.8135 | Train Loss 0.3397 | Val Loss 0.2699 |
# Epoch 053 | Time(s) 0.8219 | Train Loss 0.3330 | Val Loss 0.2662 |
# Epoch 054 | Time(s) 0.8557 | Train Loss 0.3265 | Val Loss 0.2626 |
# Epoch 055 | Time(s) 0.8450 | Train Loss 0.3203 | Val Loss 0.2591 |
# Epoch 056 | Time(s) 0.8412 | Train Loss 0.3142 | Val Loss 0.2556 |
# Epoch 057 | Time(s) 0.8712 | Train Loss 0.3083 | Val Loss 0.2523 |
# Epoch 058 | Time(s) 0.8911 | Train Loss 0.3026 | Val Loss 0.2492 |
# Epoch 059 | Time(s) 0.8885 | Train Loss 0.2970 | Val Loss 0.2461 |
# Epoch 060 | Time(s) 0.8917 | Train Loss 0.2916 | Val Loss 0.2431 |
# Epoch 061 | Time(s) 0.8911 | Train Loss 0.2863 | Val Loss 0.2402 |
# Epoch 062 | Time(s) 0.9024 | Train Loss 0.2812 | Val Loss 0.2374 |
# Epoch 063 | Time(s) 0.8934 | Train Loss 0.2763 | Val Loss 0.2347 |
# Epoch 064 | Time(s) 0.8990 | Train Loss 0.2714 | Val Loss 0.2320 |
# Epoch 065 | Time(s) 0.8900 | Train Loss 0.2667 | Val Loss 0.2294 |
# Epoch 066 | Time(s) 0.8904 | Train Loss 0.2621 | Val Loss 0.2269 |
# Epoch 067 | Time(s) 0.8627 | Train Loss 0.2577 | Val Loss 0.2244 |
# Epoch 068 | Time(s) 0.8820 | Train Loss 0.2534 | Val Loss 0.2220 |
# Epoch 069 | Time(s) 0.8857 | Train Loss 0.2491 | Val Loss 0.2197 |
# Epoch 070 | Time(s) 0.8591 | Train Loss 0.2450 | Val Loss 0.2174 |
# Epoch 071 | Time(s) 0.8535 | Train Loss 0.2410 | Val Loss 0.2152 |
# Epoch 072 | Time(s) 0.8302 | Train Loss 0.2371 | Val Loss 0.2131 |
# Epoch 073 | Time(s) 0.8660 | Train Loss 0.2333 | Val Loss 0.2110 |
# Epoch 074 | Time(s) 0.8622 | Train Loss 0.2296 | Val Loss 0.2090 |
# Epoch 075 | Time(s) 0.8682 | Train Loss 0.2260 | Val Loss 0.2070 |
# Epoch 076 | Time(s) 0.8480 | Train Loss 0.2225 | Val Loss 0.2051 |
# Epoch 077 | Time(s) 0.8438 | Train Loss 0.2191 | Val Loss 0.2032 |
# Epoch 078 | Time(s) 0.8701 | Train Loss 0.2157 | Val Loss 0.2014 |
# Epoch 079 | Time(s) 0.8710 | Train Loss 0.2125 | Val Loss 0.1996 |
# Epoch 080 | Time(s) 0.8838 | Train Loss 0.2093 | Val Loss 0.1979 |
# Epoch 081 | Time(s) 0.8957 | Train Loss 0.2062 | Val Loss 0.1962 |
# Epoch 082 | Time(s) 0.8924 | Train Loss 0.2032 | Val Loss 0.1945 |
# Epoch 083 | Time(s) 0.8905 | Train Loss 0.2003 | Val Loss 0.1929 |
# Epoch 084 | Time(s) 0.8939 | Train Loss 0.1974 | Val Loss 0.1913 |
# Epoch 085 | Time(s) 0.8855 | Train Loss 0.1945 | Val Loss 0.1897 |
# Epoch 086 | Time(s) 0.9030 | Train Loss 0.1918 | Val Loss 0.1883 |
# Epoch 087 | Time(s) 0.9106 | Train Loss 0.1890 | Val Loss 0.1868 |
# Epoch 088 | Time(s) 0.9019 | Train Loss 0.1864 | Val Loss 0.1853 |
# Epoch 089 | Time(s) 0.8992 | Train Loss 0.1838 | Val Loss 0.1839 |
# Epoch 090 | Time(s) 0.8859 | Train Loss 0.1813 | Val Loss 0.1825 |
# Epoch 091 | Time(s) 0.8841 | Train Loss 0.1788 | Val Loss 0.1812 |
# Epoch 092 | Time(s) 0.8686 | Train Loss 0.1765 | Val Loss 0.1799 |
# Epoch 093 | Time(s) 0.8432 | Train Loss 0.1741 | Val Loss 0.1785 |
# Epoch 094 | Time(s) 0.8460 | Train Loss 0.1718 | Val Loss 0.1773 |
# Epoch 095 | Time(s) 0.8994 | Train Loss 0.1695 | Val Loss 0.1760 |
# Epoch 096 | Time(s) 0.9660 | Train Loss 0.1674 | Val Loss 0.1749 |
# Epoch 097 | Time(s) 0.9632 | Train Loss 0.1652 | Val Loss 0.1737 |
# Epoch 098 | Time(s) 0.9642 | Train Loss 0.1631 | Val Loss 0.1725 |
# Epoch 099 | Time(s) 0.9680 | Train Loss 0.1610 | Val Loss 0.1714 |
# Epoch 100 | Time(s) 0.9665 | Train Loss 0.1590 | Val Loss 0.1703 |
# Epoch 101 | Time(s) 0.9923 | Train Loss 0.1570 | Val Loss 0.1692 |
# Epoch 102 | Time(s) 0.8859 | Train Loss 0.1552 | Val Loss 0.1680 |
# Epoch 103 | Time(s) 0.8758 | Train Loss 0.1531 | Val Loss 0.1669 |
# Epoch 104 | Time(s) 0.8812 | Train Loss 0.1513 | Val Loss 0.1658 |
# Epoch 105 | Time(s) 0.8942 | Train Loss 0.1494 | Val Loss 0.1649 |
# Epoch 106 | Time(s) 0.9352 | Train Loss 0.1478 | Val Loss 0.1638 |
# Epoch 107 | Time(s) 0.8852 | Train Loss 0.1458 | Val Loss 0.1628 |
# Epoch 108 | Time(s) 0.8602 | Train Loss 0.1442 | Val Loss 0.1619 |
# Epoch 109 | Time(s) 0.8599 | Train Loss 0.1425 | Val Loss 0.1609 |
# Epoch 110 | Time(s) 0.8551 | Train Loss 0.1409 | Val Loss 0.1600 |
# Epoch 111 | Time(s) 0.8318 | Train Loss 0.1391 | Val Loss 0.1591 |
# Epoch 112 | Time(s) 0.8417 | Train Loss 0.1376 | Val Loss 0.1582 |
# Epoch 113 | Time(s) 0.8855 | Train Loss 0.1360 | Val Loss 0.1573 |
# Epoch 114 | Time(s) 0.8699 | Train Loss 0.1346 | Val Loss 0.1564 |
# Epoch 115 | Time(s) 0.8795 | Train Loss 0.1329 | Val Loss 0.1556 |
# Epoch 116 | Time(s) 0.8731 | Train Loss 0.1315 | Val Loss 0.1548 |
# Epoch 117 | Time(s) 0.8757 | Train Loss 0.1300 | Val Loss 0.1540 |
# Epoch 118 | Time(s) 0.8599 | Train Loss 0.1287 | Val Loss 0.1532 |
# Epoch 119 | Time(s) 0.8625 | Train Loss 0.1272 | Val Loss 0.1524 |
# Epoch 120 | Time(s) 0.8960 | Train Loss 0.1260 | Val Loss 0.1516 |
# Epoch 121 | Time(s) 0.8765 | Train Loss 0.1245 | Val Loss 0.1509 |
# Epoch 122 | Time(s) 0.8750 | Train Loss 0.1234 | Val Loss 0.1501 |
# Epoch 123 | Time(s) 0.8479 | Train Loss 0.1219 | Val Loss 0.1494 |
# Epoch 124 | Time(s) 0.8413 | Train Loss 0.1207 | Val Loss 0.1487 |
# Epoch 125 | Time(s) 0.8573 | Train Loss 0.1194 | Val Loss 0.1480 |
# Epoch 126 | Time(s) 0.8304 | Train Loss 0.1184 | Val Loss 0.1473 |
# Epoch 127 | Time(s) 0.8410 | Train Loss 0.1169 | Val Loss 0.1467 |
# Epoch 128 | Time(s) 0.8564 | Train Loss 0.1159 | Val Loss 0.1460 |
# Epoch 129 | Time(s) 0.8360 | Train Loss 0.1146 | Val Loss 0.1454 |
# Epoch 130 | Time(s) 0.8558 | Train Loss 0.1137 | Val Loss 0.1448 |
# Epoch 131 | Time(s) 0.8795 | Train Loss 0.1124 | Val Loss 0.1442 |
# Epoch 132 | Time(s) 0.8715 | Train Loss 0.1115 | Val Loss 0.1436 |
# Epoch 133 | Time(s) 0.8675 | Train Loss 0.1102 | Val Loss 0.1430 |
# Epoch 134 | Time(s) 0.8959 | Train Loss 0.1093 | Val Loss 0.1424 |
# Epoch 135 | Time(s) 0.8839 | Train Loss 0.1081 | Val Loss 0.1418 |
# Epoch 136 | Time(s) 0.8575 | Train Loss 0.1073 | Val Loss 0.1413 |
# Epoch 137 | Time(s) 0.8797 | Train Loss 0.1061 | Val Loss 0.1407 |
# Epoch 138 | Time(s) 0.8754 | Train Loss 0.1052 | Val Loss 0.1402 |
# Epoch 139 | Time(s) 0.8654 | Train Loss 0.1042 | Val Loss 0.1397 |
# Epoch 140 | Time(s) 0.8934 | Train Loss 0.1034 | Val Loss 0.1392 |
# Epoch 141 | Time(s) 0.8851 | Train Loss 0.1022 | Val Loss 0.1386 |
# Epoch 142 | Time(s) 0.8517 | Train Loss 0.1014 | Val Loss 0.1382 |
# Epoch 143 | Time(s) 0.8675 | Train Loss 0.1003 | Val Loss 0.1376 |
# Epoch 144 | Time(s) 0.8845 | Train Loss 0.0996 | Val Loss 0.1372 |
# Epoch 145 | Time(s) 0.8451 | Train Loss 0.0986 | Val Loss 0.1366 |
# Epoch 146 | Time(s) 0.8768 | Train Loss 0.0979 | Val Loss 0.1362 |
# Epoch 147 | Time(s) 0.8822 | Train Loss 0.0968 | Val Loss 0.1357 |
# Epoch 148 | Time(s) 0.8704 | Train Loss 0.0961 | Val Loss 0.1354 |
# Epoch 149 | Time(s) 0.8786 | Train Loss 0.0952 | Val Loss 0.1348 |
# Epoch 150 | Time(s) 0.8724 | Train Loss 0.0945 | Val Loss 0.1345 |
# Epoch 151 | Time(s) 0.8614 | Train Loss 0.0935 | Val Loss 0.1339 |
# Epoch 152 | Time(s) 0.8625 | Train Loss 0.0928 | Val Loss 0.1337 |
# Epoch 153 | Time(s) 0.8665 | Train Loss 0.0919 | Val Loss 0.1331 |
# Epoch 154 | Time(s) 0.8501 | Train Loss 0.0914 | Val Loss 0.1328 |
# Epoch 155 | Time(s) 0.8559 | Train Loss 0.0903 | Val Loss 0.1322 |
# Epoch 156 | Time(s) 0.8858 | Train Loss 0.0898 | Val Loss 0.1321 |
# Epoch 157 | Time(s) 0.9092 | Train Loss 0.0890 | Val Loss 0.1315 |
# Epoch 158 | Time(s) 0.8961 | Train Loss 0.0885 | Val Loss 0.1313 |
# Epoch 159 | Time(s) 0.8990 | Train Loss 0.0875 | Val Loss 0.1307 |
# Epoch 160 | Time(s) 0.8671 | Train Loss 0.0868 | Val Loss 0.1306 |
# Epoch 161 | Time(s) 0.8989 | Train Loss 0.0860 | Val Loss 0.1300 |
# Epoch 162 | Time(s) 0.8766 | Train Loss 0.0854 | Val Loss 0.1300 |
# Epoch 163 | Time(s) 0.8667 | Train Loss 0.0846 | Val Loss 0.1293 |
# Epoch 164 | Time(s) 0.8755 | Train Loss 0.0841 | Val Loss 0.1293 |
# Epoch 165 | Time(s) 0.8845 | Train Loss 0.0835 | Val Loss 0.1288 |
# Epoch 166 | Time(s) 0.8464 | Train Loss 0.0830 | Val Loss 0.1287 |
# Epoch 167 | Time(s) 0.8530 | Train Loss 0.0821 | Val Loss 0.1281 |
# Epoch 168 | Time(s) 0.8755 | Train Loss 0.0815 | Val Loss 0.1281 |
# Epoch 169 | Time(s) 0.8273 | Train Loss 0.0807 | Val Loss 0.1274 |
# Epoch 170 | Time(s) 0.8781 | Train Loss 0.0802 | Val Loss 0.1275 |
# Epoch 171 | Time(s) 0.8726 | Train Loss 0.0795 | Val Loss 0.1269 |
# Epoch 172 | Time(s) 0.8423 | Train Loss 0.0790 | Val Loss 0.1270 |
# Epoch 173 | Time(s) 0.8699 | Train Loss 0.0783 | Val Loss 0.1263 |
# Epoch 174 | Time(s) 0.9188 | Train Loss 0.0779 | Val Loss 0.1264 |
# Epoch 175 | Time(s) 0.8777 | Train Loss 0.0773 | Val Loss 0.1259 |
# Epoch 176 | Time(s) 0.8966 | Train Loss 0.0769 | Val Loss 0.1259 |
# Epoch 177 | Time(s) 0.8891 | Train Loss 0.0761 | Val Loss 0.1253 |
# Epoch 178 | Time(s) 0.8674 | Train Loss 0.0756 | Val Loss 0.1254 |
# Epoch 179 | Time(s) 0.8679 | Train Loss 0.0749 | Val Loss 0.1248 |
# Epoch 180 | Time(s) 0.9678 | Train Loss 0.0745 | Val Loss 0.1248 |
# Epoch 181 | Time(s) 0.8843 | Train Loss 0.0739 | Val Loss 0.1243 |
# Epoch 182 | Time(s) 0.9590 | Train Loss 0.0735 | Val Loss 0.1244 |
# Epoch 183 | Time(s) 0.9537 | Train Loss 0.0729 | Val Loss 0.1238 |
# Epoch 184 | Time(s) 0.9164 | Train Loss 0.0724 | Val Loss 0.1238 |
# Epoch 185 | Time(s) 0.9087 | Train Loss 0.0717 | Val Loss 0.1233 |
# Epoch 186 | Time(s) 0.9061 | Train Loss 0.0714 | Val Loss 0.1233 |
# Epoch 187 | Time(s) 0.9087 | Train Loss 0.0707 | Val Loss 0.1229 |
# Epoch 188 | Time(s) 0.9041 | Train Loss 0.0704 | Val Loss 0.1229 |
# Epoch 189 | Time(s) 0.8980 | Train Loss 0.0697 | Val Loss 0.1225 |
# Epoch 190 | Time(s) 0.8898 | Train Loss 0.0693 | Val Loss 0.1226 |
# Epoch 191 | Time(s) 0.9047 | Train Loss 0.0687 | Val Loss 0.1221 |
# Epoch 192 | Time(s) 0.9162 | Train Loss 0.0685 | Val Loss 0.1222 |
# Epoch 193 | Time(s) 0.8809 | Train Loss 0.0680 | Val Loss 0.1217 |
# Epoch 194 | Time(s) 0.8699 | Train Loss 0.0675 | Val Loss 0.1218 |
# Epoch 195 | Time(s) 0.8338 | Train Loss 0.0668 | Val Loss 0.1213 |
# Epoch 196 | Time(s) 0.8637 | Train Loss 0.0666 | Val Loss 0.1214 |
# Epoch 197 | Time(s) 0.9147 | Train Loss 0.0660 | Val Loss 0.1210 |
# Epoch 198 | Time(s) 0.8884 | Train Loss 0.0658 | Val Loss 0.1210 |
# Epoch 199 | Time(s) 0.8907 | Train Loss 0.0651 | Val Loss 0.1206 |
# Test F1 0.974
